# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. Processing Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
from sklearn.impute import SimpleImputer

# %%
columns = [
    "C", "Si", "Mn", "S", "P", "Ni", "Cr", "Mo", "V", "Cu", "Co", "W",
    "O", "Ti", "N", "Al", "B", "Nb", "Sn", "As", "Sb",
    "Current", "Voltage", "AC_DC", "ElectrodePolarity", "HeatInput",
    "InterpassTemp", "WeldType", "PWHT_Temp", "PWHT_Time",
    "YieldStrength", "UTS", "Elongation", "ReductionArea",
    "CharpyTemp", "CharpyImpact", "Hardness", "FATT50", "PrimaryFerrite",
    "Ferrite2ndPhase", "AcicularFerrite", "Martensite", "FerriteCarbide",
    "WeldID"
]

# %%
df = pd.read_csv("../data/welddb.data", delim_whitespace=True, names=columns, na_values='N')
print(df.head())
# Out:
# C:\Users\marie\AppData\Local\Temp\ipykernel_23568\366920719.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("../data/welddb.data", delim_whitespace=True, names=columns, na_values='N')
#        C    Si    Mn      S      P   Ni  Cr   Mo    V   Cu  ... CharpyTemp  \
# 0  0.037  0.30  0.65  0.008  0.012  0.0 NaN  NaN  NaN  NaN  ...        NaN
# 1  0.037  0.30  0.65  0.008  0.012  0.0 NaN  NaN  NaN  NaN  ...      -28.0
# 2  0.037  0.30  0.65  0.008  0.012  0.0 NaN  NaN  NaN  NaN  ...      -38.0
# 3  0.037  0.31  1.03  0.007  0.014  0.0 NaN  NaN  NaN  NaN  ...        NaN
# 4  0.037  0.31  1.03  0.007  0.014  0.0 NaN  NaN  NaN  NaN  ...      -48.0
#
#   CharpyImpact  Hardness FATT50 PrimaryFerrite Ferrite2ndPhase  \
# 0          NaN       NaN    NaN            NaN             NaN
# 1        100.0       NaN    NaN            NaN             NaN
# 2        100.0       NaN    NaN            NaN             NaN
# 3          NaN       NaN    NaN            NaN             NaN
# 4        100.0       NaN    NaN             32            28.0
#
#   AcicularFerrite Martensite FerriteCarbide                         WeldID
# 0             NaN        NaN            NaN    Evans-Ni/CMn-1990/1991-0Aaw
# 1             NaN        NaN            NaN  Evans-Ni/CMn-1990/1991-0Aawch
# 2             NaN        NaN            NaN    Evans-Ni/CMn-1990/1991-0Aht
# 3             NaN        NaN            NaN    Evans-Ni/CMn-1990/1991-0Baw
# 4            40.0        0.0            0.0  Evans-Ni/CMn-1990/1991-0Bawch
#
# [5 rows x 44 columns]

# %%
df
# Out:
#           C    Si    Mn      S      P    Ni    Cr    Mo     V   Cu  ...  \
# 0     0.037  0.30  0.65  0.008  0.012  0.00   NaN   NaN   NaN  NaN  ...
# 1     0.037  0.30  0.65  0.008  0.012  0.00   NaN   NaN   NaN  NaN  ...
# 2     0.037  0.30  0.65  0.008  0.012  0.00   NaN   NaN   NaN  NaN  ...
# 3     0.037  0.31  1.03  0.007  0.014  0.00   NaN   NaN   NaN  NaN  ...
# 4     0.037  0.31  1.03  0.007  0.014  0.00   NaN   NaN   NaN  NaN  ...
# ...     ...   ...   ...    ...    ...   ...   ...   ...   ...  ...  ...
# 1647  0.100  0.35  0.90  0.008  0.016  0.60   8.6  0.98  0.18  NaN  ...
# 1648  0.088  0.36  0.88  0.008  0.017  0.57   8.4  0.94  0.19  NaN  ...
# 1649  0.090  0.34  0.89  0.008  0.016  0.17   8.2  0.94  0.02  NaN  ...
# 1650  0.092  0.35  0.90  0.008  0.016  0.54   8.4  0.97  0.17  NaN  ...
# 1651  0.180  0.39  0.88  0.008  0.017  0.18  10.2  0.94  0.28  NaN  ...
#
#      CharpyTemp CharpyImpact  Hardness FATT50 PrimaryFerrite Ferrite2ndPhase  \
# 0           NaN          NaN       NaN    NaN            NaN             NaN
# 1         -28.0        100.0       NaN    NaN            NaN             NaN
# 2         -38.0        100.0       NaN    NaN            NaN             NaN
# 3           NaN          NaN       NaN    NaN            NaN             NaN
# 4         -48.0        100.0       NaN    NaN             32            28.0
# ...         ...          ...       ...    ...            ...             ...
# 1647        NaN          NaN       NaN    NaN            NaN             NaN
# 1648        NaN          NaN       NaN    NaN            NaN             NaN
# 1649        NaN          NaN       NaN    NaN            NaN             NaN
# 1650        NaN          NaN       NaN    NaN            NaN             NaN
# 1651        NaN          NaN       NaN    NaN            NaN             NaN
#
#      AcicularFerrite Martensite FerriteCarbide                         WeldID
# 0                NaN        NaN            NaN    Evans-Ni/CMn-1990/1991-0Aaw
# 1                NaN        NaN            NaN  Evans-Ni/CMn-1990/1991-0Aawch
# 2                NaN        NaN            NaN    Evans-Ni/CMn-1990/1991-0Aht
# 3                NaN        NaN            NaN    Evans-Ni/CMn-1990/1991-0Baw
# 4               40.0        0.0            0.0  Evans-Ni/CMn-1990/1991-0Bawch
# ...              ...        ...            ...                            ...
# 1647             NaN        NaN            NaN               Birmingham-MAX35
# 1648             NaN        NaN            NaN               Birmingham-MAX36
# 1649             NaN        NaN            NaN               Birmingham-MAX37
# 1650             NaN        NaN            NaN               Birmingham-MAX38
# 1651             NaN        NaN            NaN               Birmingham-MAX39
#
# [1652 rows x 44 columns]

# %% [markdown]
# ## 2. Cleaning and preprocessing

# %%
print(df.isna().sum()/df.count())
# Out:
# C                     0.000000
# Si                    0.000000
# Mn                    0.000000
# S                     0.002427
# P                     0.006090
# Ni                    1.370158
# Cr                    1.107143
# Mo                    1.083228
# V                     0.780172
# Cu                    1.858131
# Co                   11.806202
# W                    21.026667
# O                     0.315287
# Ti                    0.766845
# N                     0.330113
# Al                    0.825414
# B                     2.277778
# Nb                    1.196809
# Sn                    4.581081
# As                    6.059829
# Sb                    5.353846
# Current               0.176638
# Voltage               0.176638
# AC_DC                 0.149617
# ElectrodePolarity     0.104278
# HeatInput             0.000000
# InterpassTemp         0.000000
# WeldType              0.000000
# PWHT_Temp             0.007932
# PWHT_Time             0.007932
# YieldStrength         1.117949
# UTS                   1.238482
# Elongation            1.360000
# ReductionArea         1.343262
# CharpyTemp            0.879408
# CharpyImpact          0.879408
# Hardness             10.971014
# FATT50               52.290323
# PrimaryFerrite       15.857143
# Ferrite2ndPhase      17.355556
# AcicularFerrite      17.355556
# Martensite           17.561798
# FerriteCarbide       17.561798
# WeldID                0.000000
# dtype: float64

# %% [markdown]
# A lot of data is missing.

# %%
msno.matrix(df)
plt.show()

# %% [markdown]
# Interpretation:
# - Each column = one variable (chemistry, process, mechanics, microstructure, etc.).
# - Each row = one sample (one welding filler metal).
# - Black = missing data, white = data present.
#
# The bar on the right shows the number of missing values per row.

# %% [markdown]
# We can see:
# - The first columns (C, Si, Mn, etc.) are almost entirely filled in.
# - Columns such as Ti, Al, Nb, Sn, etc. have many missing values (probably because they were not measured in certain studies).
# - Mechanical properties (YS, UTS, elongation, etc.) are partially available.
# - The microstructure (ferrite, martensite, etc.) is very incomplete.

# %%
print(df.dtypes)
# Out:
# C                    float64
# Si                   float64
# Mn                   float64
# S                     object
# P                    float64
# Ni                   float64
# Cr                   float64
# Mo                    object
# V                     object
# Cu                    object
# Co                    object
# W                     object
# O                    float64
# Ti                    object
# N                     object
# Al                    object
# B                     object
# Nb                    object
# Sn                    object
# As                    object
# Sb                    object
# Current              float64
# Voltage              float64
# AC_DC                 object
# ElectrodePolarity     object
# HeatInput            float64
# InterpassTemp         object
# WeldType              object
# PWHT_Temp            float64
# PWHT_Time            float64
# YieldStrength        float64
# UTS                  float64
# Elongation           float64
# ReductionArea        float64
# CharpyTemp           float64
# CharpyImpact         float64
# Hardness              object
# FATT50               float64
# PrimaryFerrite        object
# Ferrite2ndPhase      float64
# AcicularFerrite      float64
# Martensite           float64
# FerriteCarbide       float64
# WeldID                object
# dtype: object

# %% [markdown]
# Finding whether they are MNAR, MAR, MCAR:

# %% [markdown]
# We keep for this step only the numerical values:

# %%
df_num = df.select_dtypes(include=np.number)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isna().corr(), cmap="coolwarm", center=0)
plt.title("Correlation between missingness patterns")
plt.show()

# %% [markdown]
# Thus we can try to intute patterns MAR, MCAR and MNAR:
# - **MCAR**: correlations in the heatmap are close to 0 everywhere
# - **MAR**: strong correlations between patterns of missing data
# - **MNAR**: difficult to prove directly
#
# Thus:
# - **Chemical elements** (C, Mn, Cr, etc.) might be **MAR** : Correlated missing data between elements: depends on the analytical protocol
# - **Mechanical properties** (YieldStrength, UTS, Elongation, etc.) might be **MAR** as well: Data missing together, therefore related to the availability of mechanical tests.
# - **Microstructure** (PrimaryFerrite, AcicularFerrite, FerriteCarbide) might be **MNAR**: Probably absent when the microstructure is complex or not measured (non-random).
# - **Process parameters** (Voltage, Polarity, InterpassTemp) might be **MCAR** or quasi-MCAR: Little or no correlation with other patterns of missing data.

# %% [markdown]
# ### MCAR (Missing Completely at Random)

# %% [markdown]
# Values are missing without any particular logic: they can be deleted or simply imputed.
#
# **Strategy**:
# - If there is little missing data (<5%), you can delete the relevant rows (dropna).
# - Otherwise, simple imputation: mean or median (SimpleImputer(strategy=‘median’))..

# %%
df.columns
# Out:
# Index(['C', 'Si', 'Mn', 'S', 'P', 'Ni', 'Cr', 'Mo', 'V', 'Cu', 'Co', 'W', 'O',
#        'Ti', 'N', 'Al', 'B', 'Nb', 'Sn', 'As', 'Sb', 'Current', 'Voltage',
#        'AC_DC', 'ElectrodePolarity', 'HeatInput', 'InterpassTemp', 'WeldType',
#        'PWHT_Temp', 'PWHT_Time', 'YieldStrength', 'UTS', 'Elongation',
#        'ReductionArea', 'CharpyTemp', 'CharpyImpact', 'Hardness', 'FATT50',
#        'PrimaryFerrite', 'Ferrite2ndPhase', 'AcicularFerrite', 'Martensite',
#        'FerriteCarbide', 'WeldID'],
#       dtype='object')

# %%
process_param_columns = ['Current', 'Voltage','AC_DC', 'ElectrodePolarity', 'HeatInput', 'InterpassTemp', 'WeldType', 'PWHT_Temp', 'PWHT_Time']
print("Percentage of missing values:\n", df[process_param_columns].isna().sum()/df[process_param_columns].count())
# Out:
# Percentage of missing values:
#  Current              0.176638
# Voltage              0.176638
# AC_DC                0.149617
# ElectrodePolarity    0.104278
# HeatInput            0.000000
# InterpassTemp        0.000000
# WeldType             0.000000
# PWHT_Temp            0.007932
# PWHT_Time            0.007932
# dtype: float64

# %%
# Numeric columns to impute with median
num_cols = ['Current', 'Voltage']
num_imputer = SimpleImputer(strategy='median')
df[num_cols] = num_imputer.fit_transform(df[num_cols])

# Categorical columns to impute with mode
cat_cols = ['AC_DC', 'ElectrodePolarity']
cat_imputer = SimpleImputer(strategy='most_frequent')
df[cat_cols] = cat_imputer.fit_transform(df[cat_cols])

# Columns with very low missing data (<1%) - optional to drop
df.dropna(subset=['PWHT_Temp', 'PWHT_Time'], inplace=True)

# %% [markdown]
# ### MAR (Missing At Random)

# %% [markdown]
# Chemical composition have missing values which depends on analytical protocol (e.g., some elements measured together).
#
# **Strategy**:
# - Use multivariate imputation that leverages relationships between chemical elements
# - Alternatively, use KNN imputation if we expect local similarity between alloys

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
chem_cols = ['C', 'Si', 'Mn', 'S', 'P', 'Ni', 'Cr', 'Mo', 'V', 'Cu', 'Co', 'W', 'O','Ti', 'N', 'Al', 'B', 'Nb', 'Sn', 'As', 'Sb']

# %%
non_numeric = df[chem_cols].select_dtypes(include='object').columns

# %%
df[chem_cols] = df[chem_cols].replace(',', '.', regex=True)
df[chem_cols] = df[chem_cols].replace(r'[<>]|ND|nd|Na|NA', '', regex=True)
df[chem_cols] = df[chem_cols].apply(pd.to_numeric, errors='coerce')

# %%
imp = IterativeImputer(random_state=0)
df[chem_cols] = imp.fit_transform(df[chem_cols])

# %%
df[chem_cols].head()
# Out:
#        C    Si    Mn      S      P   Ni        Cr        Mo         V  \
# 0  0.037  0.30  0.65  0.008  0.012  0.0  2.189899  0.618717  0.074500
# 1  0.037  0.30  0.65  0.008  0.012  0.0  2.189899  0.618717  0.074500
# 2  0.037  0.30  0.65  0.008  0.012  0.0  2.189899  0.618717  0.074500
# 3  0.037  0.31  1.03  0.007  0.014  0.0  1.758652  0.504925  0.075191
# 4  0.037  0.31  1.03  0.007  0.014  0.0  1.758652  0.504925  0.075191
#
#          Cu  ...         W           O         Ti           N         Al  \
# 0  0.203616  ...  0.085422  443.125592  80.384739  116.852837  64.058067
# 1  0.203616  ...  0.085422  443.125592  80.384739  116.852837  64.058067
# 2  0.203616  ...  0.085422  443.125592  80.384739  116.852837  64.058067
# 3  0.192290  ...  0.163458  442.823038  81.431936  115.045512  78.110745
# 4  0.192290  ...  0.163458  442.823038  81.431936  115.045512  78.110745
#
#            B          Nb         Sn         As         Sb
# 0  10.452024  146.503829  50.226706  38.279413  21.883806
# 1  10.452024  146.503829  50.226706  38.279413  21.883806
# 2  10.452024  146.503829  50.226706  38.279413  21.883806
# 3   9.952040  131.027189  50.292401  37.489562  23.024268
# 4   9.952040  131.027189  50.292401  37.489562  23.024268
#
# [5 rows x 21 columns]

# %% [markdown]
# Mechanical properties (e.g., YieldStrength, UTS, Elongation, ImpactEnergy, Hardness, etc.) are missing altogether when mechanical tests have not been performed.
# Therefore, their values are correlated with each other:
#
# **Strategy**:
# - Multivariate imputation

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df.columns
# Out:
# Index(['C', 'Si', 'Mn', 'S', 'P', 'Ni', 'Cr', 'Mo', 'V', 'Cu', 'Co', 'W', 'O',
#        'Ti', 'N', 'Al', 'B', 'Nb', 'Sn', 'As', 'Sb', 'Current', 'Voltage',
#        'AC_DC', 'ElectrodePolarity', 'HeatInput', 'InterpassTemp', 'WeldType',
#        'PWHT_Temp', 'PWHT_Time', 'YieldStrength', 'UTS', 'Elongation',
#        'ReductionArea', 'CharpyTemp', 'CharpyImpact', 'Hardness', 'FATT50',
#        'PrimaryFerrite', 'Ferrite2ndPhase', 'AcicularFerrite', 'Martensite',
#        'FerriteCarbide', 'WeldID'],
#       dtype='object')

# %%
mech_cols = [
    'YieldStrength', 'UTS', 'Elongation', 'ReductionArea',
    'CharpyTemp', 'CharpyImpact', 'Hardness', 'FATT50'
]

# %% [markdown]
# Before imputing, we create a binary feature indicating whether a mechanical test has been performed:

# %%
df['MechanicalTestDone'] = (~df[mech_cols].isna().all(axis=1)).astype(int)

# %%
df['MechanicalTestDone'].describe()
# Out:
# count    1639.000000
# mean        0.968883
# std         0.173686
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: MechanicalTestDone, dtype: float64

# %% [markdown]
# Hardness seems to have units :
# - ex: 246Hv10, 144(Hv30), 212Hv10

# %% [markdown]
# Hardness Units:
# | Scale  | Meaning          | Approximate unit |
# | ------ | ---------------- | ---------------- |
# | HV     | Vickers Hardness | kgf/mm²          |
# | HB     | Brinell Hardness | kgf/mm²          |
# | HRC    | Rockwell C       | relative scale   |
# | HRB    | Rockwell B       | relative scale   |
# | kg/mm² | direct unit      | equivalent to HV |

# %% [markdown]
# Since we only have HV values (Hv5, Hv10, Hv30), there’s no need for unit conversion. These are all Vickers hardness values, just measured with different indenter loads. Thus we can just strip the unit:

# %%
df['Hardness'] = (
    df['Hardness'].astype(str)
    .str.extract(r'([0-9]*\.?[0-9]+)')[0]  # take only the number
    .astype(float)
)

# %%
imp_mech = IterativeImputer(random_state=0, max_iter=10)
df[mech_cols] = imp_mech.fit_transform(df[mech_cols])

# %%
df[mech_cols]
# Out:
#       YieldStrength         UTS  Elongation  ReductionArea  CharpyTemp  \
# 0        392.000000  466.000000   31.900000      80.600000  -62.340600
# 1        539.480878  595.361724   24.368108      73.790987  -28.000000
# 2        370.000000  456.000000   35.200000      80.600000  -38.000000
# 3        413.000000  498.000000   31.200000      80.600000  -56.406404
# 4        577.170399  599.082061   25.135567      78.553386  -48.000000
# ...             ...         ...         ...            ...         ...
# 1647     834.000000  667.602345   20.857861      94.537711  -86.813971
# 1648     822.000000  665.023941   21.058350      93.720445  -84.914582
# 1649     660.000000  630.215482   23.764950      82.687356  -59.272823
# 1650     832.000000  667.172611   20.891275      94.401500  -86.497406
# 1651     505.100526  596.454131   26.366462      72.208883  -34.954815
#
#       CharpyImpact    Hardness     FATT50
# 0       100.437073  167.793989 -31.606895
# 1       100.000000  709.271474 -30.930308
# 2       100.000000  859.509579 -30.955908
# 3        96.586268  181.983998 -31.490512
# 4       100.000000  354.142979 -31.418184
# ...            ...         ...        ...
# 1647    120.767143  319.270652 -32.556854
# 1648    119.560904  315.065070 -32.500969
# 1649    103.276665  258.289714 -31.746528
# 1650    120.566103  318.569721 -32.547540
# 1651     87.833099  204.403818 -31.030139
#
# [1639 rows x 8 columns]

# %% [markdown]
# ### MNAR (Missing Not At Random)

# %% [markdown]
# Microstructure columns, which are likely MNAR (Missing Not At Random). That means:
#
# The missingness depends on the data itself.
#
# Example: If the microstructure is complex, certain features may simply not be measured.

# %%
micro_cols = [
    'PrimaryFerrite', 'Ferrite2ndPhase', 'AcicularFerrite',
    'Martensite', 'FerriteCarbide'
]

# %% [markdown]
# We shouldn’t blindly impute MNAR values, because filling them in with “typical” numbers can introduce bias.

# %% [markdown]
# So we'll leave them as is and change them only if the chosen model can't handle missing values and we'll then add a missingness indicator : a flag column (0/1) telling the model whether any microstructure info is missing: missingness itself becomes a useful feature

# %%
df.to_csv('dataset_cleaned_2025_10_18.csv', index=False)

# %% [markdown]
# ## 3. Outlier detection

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns.tolist()

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Histogram + KDE of {col}')
    plt.show()

# %%
skewness = df[numeric_cols].skew()
skewness.sort_values(ascending=False)
# Out:
# V                  12.668854
# P                  10.805622
# S                   9.703553
# Martensite          9.433981
# Sn                  5.659366
# FerriteCarbide      3.616863
# B                   3.397389
# N                   3.185140
# Voltage             3.129640
# Ti                  3.045889
# Nb                  3.036061
# Cu                  3.008974
# Co                  2.787305
# HeatInput           2.411818
# Cr                  2.402170
# Al                  2.311339
# Ni                  1.711736
# Current             1.686419
# W                   1.657217
# Si                  1.620403
# UTS                 1.437551
# Ferrite2ndPhase     1.264260
# As                  1.249975
# PWHT_Time           0.879038
# C                   0.843511
# Hardness            0.774952
# CharpyTemp          0.760724
# CharpyImpact        0.660050
# Mo                  0.605350
# YieldStrength       0.460202
# PWHT_Temp           0.270639
# Mn                  0.097503
# Elongation         -0.498196
# ReductionArea      -0.614747
# AcicularFerrite    -0.655017
# O                  -3.651905
# Sb                 -5.026938
# FATT50             -5.483218
# dtype: float64

# %% [markdown]
# **Strategy**:
# - Highly positively skewed: skew > 1 → consider log transform
# - Moderately skewed: 0.5 < skew < 1 → optional
# - Symmetric: -0.5 < skew < 0.5 → no transform
# - Negatively skewed: skew < -1 → consider reflection + log / other transform

# %% [markdown]
# We'll logtransform highly positive skews

# %%
log_cols = ['V', 'P', 'S', 'Sn', 'B', 'N', 'Voltage', 'Ti', 'Nb', 'Cu']

for col in log_cols:
    df[col+'_log'] = np.log1p(df[col])
# Out:
# c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.describe()
# Out:
#                  C           Si           Mn            S            P  \
# count  1639.000000  1639.000000  1639.000000  1639.000000  1639.000000
# mean      0.075175     0.328603     1.200134     0.009481     0.012948
# std       0.023635     0.112800     0.382271     0.011227     0.019642
# min       0.029000     0.040000     0.270000     0.001000     0.002000
# 25%       0.061000     0.270000     0.930000     0.006000     0.007000
# 50%       0.074000     0.320000     1.250000     0.007000     0.010000
# 75%       0.084000     0.360000     1.440000     0.010000     0.014000
# max       0.180000     1.140000     2.250000     0.140000     0.250000
#
#                 Ni           Cr           Mo            V           Cu  ...  \
# count  1639.000000  1639.000000  1639.000000  1639.000000  1639.000000  ...
# mean      0.475521     1.588588     0.428598     0.083858     0.164483  ...
# std       0.612673     2.249508     0.361248     0.372279     0.222313  ...
# min      -1.308202    -0.542971    -0.332158    -0.130994    -0.327498  ...
# 25%       0.060000     0.082572     0.151862     0.000500     0.020000  ...
# 50%       0.442821     0.952473     0.362502     0.050000     0.159022  ...
# 75%       0.684598     2.070000     0.608959     0.083000     0.226618  ...
# max       3.500000    10.200000     1.500000     5.000000     1.630000  ...
#
#              V_log        P_log        S_log       Sn_log        B_log  \
# count  1639.000000  1639.000000  1639.000000  1514.000000  1616.000000
# mean      0.062537     0.012700     0.009378     3.715839     2.214794
# std       0.144062     0.017639     0.010571     1.291313     0.539974
# min      -0.140405     0.001998     0.001000    -4.217442    -2.091892
# 25%       0.000500     0.006976     0.005982     3.866741     1.791759
# 50%       0.048790     0.009950     0.006976     4.066649     2.243243
# 75%       0.079735     0.013903     0.009950     4.331571     2.430897
# max       1.791759     0.223144     0.131028     6.908755     4.248495
#
#              N_log  Voltage_log       Ti_log       Nb_log       Cu_log
# count  1639.000000  1639.000000  1636.000000  1638.000000  1639.000000
# mean      4.548779     3.259991     4.016522     3.946010     0.137735
# std       0.504506     0.298765     1.081326     1.608449     0.163347
# min       3.091042     2.525729     0.000000     0.000000    -0.396751
# 25%       4.309393     3.091042     3.637586     1.945910     0.019803
# 50%       4.488636     3.091042     4.406473     4.540302     0.147577
# 75%       4.700886     3.401197     4.567054     4.907634     0.204260
# max       6.315358     4.335459     6.538140     6.908755     0.966984
#
# [8 rows x 49 columns]

# %%
for col in log_cols:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution & KDE of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()
